# %% [markdown]
# ## Heatmap
# https://plot.ly/python/heatmaps/
#
# A heatmap is a graphical representation of data where the individual values contained in a matrix are represented as colors.

# %% [markdown]
# ### Importing packages

# %%
import plotly.graph_objs as go
import plotly.offline as offline

offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ##### plotting simple heatmap with two rows and two columns

# %%
trace = go.Heatmap(z = [[8, 64],
                        [3, 37]])

# %%
data = [trace]

offline.iplot(data)
# Out:
# <div>
#
#
#             <div id="bed50336-7f68-4bfd-bacc-6f5979b95c3b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bed50336-7f68-4bfd-bacc-6f5979b95c3b")) {
#                     Plotly.newPlot(
#                         'bed50336-7f68-4bfd-bacc-6f5979b95c3b',
#                         [{"type": "heatmap", "z": [[8, 64], [3, 37]]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %% [markdown]
# ##### Ploting heatmap with three rows and three columns

# %%
trace = go.Heatmap(z = [[8, 64, 98],
                        [3, 37, 18],
                        [55, 23, 41]])

# %%
data = [trace]

offline.iplot(data)
# Out:
# <div>
#
#
#             <div id="9b33ad3a-9f0a-4a8a-bae2-32ebc057e748" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9b33ad3a-9f0a-4a8a-bae2-32ebc057e748")) {
#                     Plotly.newPlot(
#                         '9b33ad3a-9f0a-4a8a-bae2-32ebc057e748',
#                         [{"type": "heatmap", "z": [[8, 64, 98], [3, 37, 18], [55, 23, 41]]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %% [markdown]
# ##### Loading california housing dataset

# %%
import pandas as pd

housing_data = pd.read_csv('datasets/housing.csv')

housing_data.sample(10)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1988     -119.81     36.74                36.0        607.0           155.0
# 12248    -117.01     33.75                15.0       2873.0           903.0
# 13328    -117.66     34.05                 6.0       5129.0          1119.0
# 15704    -122.43     37.79                52.0       3219.0           969.0
# 7772     -118.10     33.91                35.0       1592.0           335.0
# 3358     -120.66     40.41                52.0       2081.0           478.0
# 4528     -118.22     34.04                43.0        798.0           308.0
# 13584    -117.30     34.13                42.0       2115.0           557.0
# 2666     -115.52     33.13                18.0       1109.0           283.0
# 11164    -118.00     33.82                18.0       2947.0           559.0
#
#        population  households  median_income  median_house_value  \
# 1988        483.0       146.0         1.5625             47500.0
# 12248      1094.0       659.0         1.8015            105100.0
# 13328      2533.0       949.0         3.6250            113600.0
# 15704      1152.0       830.0         4.2042            500001.0
# 7772       1238.0       320.0         4.9732            165000.0
# 3358       1051.0       419.0         2.2992             70200.0
# 4528       1417.0       325.0         1.4189            141700.0
# 13584      1532.0       494.0         1.4531             71500.0
# 2666       1006.0       253.0         2.1630             53400.0
# 11164      1820.0       551.0         4.5294            224800.0
#
#       ocean_proximity
# 1988           INLAND
# 12248          INLAND
# 13328          INLAND
# 15704        NEAR BAY
# 7772        <1H OCEAN
# 3358           INLAND
# 4528        <1H OCEAN
# 13584          INLAND
# 2666           INLAND
# 11164       <1H OCEAN

# %%
housing_data.shape
# Out:
# (20640, 10)

# %%
housing_data = housing_data.sample(frac=0.1).reset_index(drop=True)

housing_data.shape
# Out:
# (2064, 10)

# %%
median = housing_data['median_house_value'].median()

median
# Out:
# 177800.0

# %% [markdown]
# ##### Adding one column 'above_median' in the dataset for median_house_value is greater or lesser than median value of the whole column values

# %%
housing_data['above_median'] = (housing_data['median_house_value'] - median) > 0

housing_data.sample(5)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 647     -123.54     39.17                18.0       2251.0           510.0
# 1745    -119.03     35.36                41.0       2551.0           594.0
# 1637    -118.12     33.98                44.0        932.0           179.0
# 1006    -122.18     37.76                52.0        754.0           175.0
# 932     -117.00     32.70                23.0       2785.0           468.0
#
#       population  households  median_income  median_house_value  \
# 647       1032.0       369.0         2.2946            101000.0
# 1745      1342.0       595.0         1.9671             76800.0
# 1637       717.0       180.0         3.6875            178100.0
# 1006       447.0       165.0         3.9063             93800.0
# 932       1456.0       449.0         4.3714            131000.0
#
#      ocean_proximity  above_median
# 647        <1H OCEAN         False
# 1745          INLAND         False
# 1637       <1H OCEAN          True
# 1006        NEAR BAY         False
# 932       NEAR OCEAN         False

# %% [markdown]
# ##### Plotting heatmap as ocean_proximity on x axis and above_median on y axis

# %%
trace = go.Heatmap(z = housing_data['median_house_value'],
                   
                   x = housing_data['ocean_proximity'],
                   
                   y = housing_data['above_median'],
                   
                   colorscale = 'Jet',
                   
                   reversescale = True
                  )

# %%
data = [trace]

offline.iplot(data)
# Out:
# <div>
#
#
#             <div id="7259a012-1c36-411c-8fee-50c2c7208234" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7259a012-1c36-411c-8fee-50c2c7208234")) {
#                     Plotly.newPlot(
#                         '7259a012-1c36-411c-8fee-50c2c7208234',
#                         [{"colorscale": [[0.0, "rgb(0,0,131)"], [0.2, "rgb(0,60,170)"], [0.4, "rgb(5,255,255)"], [0.6, "rgb(255,255,0)"], [0.8, "rgb(250,0,0)"], [1.0, "rgb(128,0,0)"]], "reversescale": true, "type": "heatmap", "x": ["<1H OCEAN", "<1H OCEAN", "INLAND", "NEAR BAY", "NEAR OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "NEAR BAY", "INLAND", "<1H OCEAN", "INLAND", "INLAND", "<1H OCEAN", "INLAND", "<1H OCEAN", "NEAR OCEAN", "<1H OCEAN", "INLAND", "NEAR BAY", "INLAND", "<1H OCEAN", "INLAND", "<1H OCEAN", "NEAR BAY", "INLAND", "<1H OCEAN", "INLAND", "INLAND", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "NEAR OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "INLAND", "<1H OCEAN", "NEAR OCEAN", "<1H OCEAN", "INLAND", "INLAND", "INLAND", "NEAR OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "INLAND", "NEAR BAY", "NEAR OCEAN", "<1H OCEAN", "INLAND", "NEAR BAY", "INLAND", "<1H OCEAN", "INLAND", "<1H OCEAN", "NEAR OCEAN", "INLAND", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "NEAR BAY", "<1H OCEAN", "<1H OCEAN", "INLAND", "INLAND", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "NEAR OCEAN", "<1H OCEAN", "NEAR OCEAN", "NEAR OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "NEAR OCEAN", "INLAND", "INLAND", "INLAND", "NEAR OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "INLAND", "INLAND", "NEAR BAY", "<1H OCEAN", "<1H OCEAN", "NEAR BAY", "<1H OCEAN", "INLAND", "NEAR OCEAN", "NEAR BAY", "NEAR OCEAN", "INLAND", "NEAR BAY", "<1H OCEAN", "INLAND", "INLAND", "<1H OCEAN", "INLAND", "<1H OCEAN", "NEAR BAY", "NEAR BAY", "INLAND", "INLAND", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "INLAND", "INLAND", "<1H OCEAN", "NEAR BAY", "<1H OCEAN", "NEAR OCEAN", "NEAR OCEAN", "<1H OCEAN", "INLAND", "INLAND", "<1H OCEAN", "INLAND", "INLAND", "INLAND", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "NEAR BAY", "<1H OCEAN", "<1H OCEAN", "NEAR OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "INLAND", "NEAR OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "INLAND", "INLAND", "<1H OCEAN", "NEAR OCEAN", "INLAND", "NEAR BAY", "<1H OCEAN", "INLAND", "NEAR BAY", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "NEAR BAY", "INLAND", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "NEAR BAY", "INLAND", "<1H OCEAN", "INLAND", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "INLAND", "NEAR OCEAN", "INLAND", "INLAND", "<1H OCEAN", "<1H OCEAN", "NEAR OCEAN", "NEAR OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "NEAR OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "NEAR BAY", "INLAND", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "NEAR OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "NEAR BAY", "<1H OCEAN", "<1H OCEAN", "NEAR OCEAN", "<1H OCEAN", "NEAR BAY", "INLAND", "NEAR OCEAN", "INLAND", "INLAND", "NEAR BAY", "<1H OCEAN", "<1H OCEAN", "NEAR OCEAN", "<1H OCEAN", "INLAND", "INLAND", "NEAR OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "NEAR BAY", "<1H OCEAN", "INLAND", "INLAND", "INLAND", "INLAND", "INLAND", "NEAR OCEAN", "<1H OCEAN", "INLAND", "NEAR BAY", "NEAR OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "NEAR BAY", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "NEAR OCE ...
